# %%
import numpy as np
arr1=np.array([1,2,3,4,5,6])
print(arr1)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as ny
arr1=np.array([1,2,3,4])
print(arr1)
arr2d=np.array([[1,2],[3,4]])
print(arr2d)
# Out:
# [1 2 3 4]
# [[1 2]
#  [3 4]]
