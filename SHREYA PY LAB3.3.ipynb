# %%
d1={"a":1,"b":2}
d2={"c":3,"d":4}
d3=d1.copy()
print(d3)
print(d3.clear())
print(d2.fromkeys("c"))
print(d1.get("b"))
print(d2.keys())
print(d2.values())
print(d2.pop("d"))
print(d2)
print(d1.popitem())
print(d1)
d1.setdefault("e",8)
d1.update(a=5)
print(d1)
merge = d1 | d2
print(merge)
# Out:
# {'a': 1, 'b': 2}
# None
# {'c': None}
# 2
# dict_keys(['c', 'd'])
# dict_values([3, 4])
# 4
# {'c': 3}
# ('b', 2)
# {'a': 1}
# {'a': 5, 'e': 8}
# {'a': 5, 'e': 8, 'c': 3}
