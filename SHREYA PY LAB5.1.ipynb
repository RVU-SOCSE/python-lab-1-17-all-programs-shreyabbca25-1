# %%
import pandas as pd
data=pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data=pd.Series([10,20,30],index=["x","y","z"])
print(data)
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %%
data={
    "Name":["Ram","Vani"],
    "Age":[20,25]
}

df=pd.DataFrame(data)
print(df)
print("\n")

print(df.loc[0])
